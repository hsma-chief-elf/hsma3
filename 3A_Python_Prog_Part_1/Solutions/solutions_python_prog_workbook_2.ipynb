# %% [markdown]
# # Python Programming Workbook 2 - SOLUTIONS

# %% [markdown]
# This workbook is intended to accompany Session 3A of the HSMA Training Programme - Python Programming Part 1.  You should be completing this when prompted by the trainer as Exercise 3 of the session.  You should read each task, and then try to write code to achieve what you are being asked in the code cell below each set of instructions.  Remember - check your code is working by running the code cell (CTRL + Enter whilst in the cell, or click the play button in the bar at the top).

# %% [markdown]
# **Task 1**
# Write a piece of code that asks the user to input a number, and the machine then prints out the times table (from 1 x up to and including 12 x the number) for whatever number is entered.

# %%
chosen_number = int(input("Please input a number : "))

for x in range(1,13):
    print (x, " x ", chosen_number, " is ", (x * chosen_number), sep="")
# Out:
# Please input a number :  5
# 1 x 5 is 5
# 2 x 5 is 10
# 3 x 5 is 15
# 4 x 5 is 20
# 5 x 5 is 25
# 6 x 5 is 30
# 7 x 5 is 35
# 8 x 5 is 40
# 9 x 5 is 45
# 10 x 5 is 50
# 11 x 5 is 55
# 12 x 5 is 60

# %% [markdown]
# **Task 2** Write code that sets up a new list called penchord_team with the initial values "Dan", "Mike", "Tom", "Sean", "Kerry", "Andy", "Alison", "Martin" and "Sarah", and iterates through the list saying hello to each team member.

# %%
penchord_team = ["Dan", "Mike", "Tom", "Sean", "Kerry", "Andy", "Alison", "Martin", "Sarah"]

for team_member in penchord_team:
    print ("Hello ", team_member, sep="")
# Out:
# Hello Dan
# Hello Mike
# Hello Tom
# Hello Sean
# Hello Kerry
# Hello Andy
# Hello Alison
# Hello Martin
# Hello Sarah

# %% [markdown]
# **Task 3** Write a piece of code that asks the user to input a number, and will keep asking the user to input a number until the number entered is more than 100.  However, if the user enters 0 then the program exits with an appropriate message.

# %%
user_number = int(input("Please enter a number : "))

while (user_number <= 100):
    if user_number == 0:
        print ("Exiting program")
        break
    else:
        user_number = int(input("Please enter a number : "))
# Out:
# Please enter a number :  0
# Exiting program

# %% [markdown]
# **Task 4** **This task is a little more challenging.  Think carefully about how you will approach this problem.** Write a piece of code that counts up day numbers from 2 to 364 (inclusive), and displays a message giving the day number every 2nd day, and additionally displays a reminder to "go shopping" every 4 days.

# %%
for day in range(2,365,2):
    print ("Day ", day)
    if day % 4 == 0:
        print ("Go shopping!")
# Out:
# Day  2
# Day  4
# Go shopping!
# Day  6
# Day  8
# Go shopping!
# Day  10
# Day  12
# Go shopping!
# Day  14
# Day  16
# Go shopping!
# Day  18
# Day  20
# Go shopping!
# Day  22
# Day  24
# Go shopping!
# Day  26
# Day  28
# Go shopping!
# Day  30
# Day  32
# Go shopping!
# Day  34
# Day  36
# Go shopping!
# Day  38
# Day  40
# Go shopping!
# Day  42
# Day  44
# Go shopping!
# Day  46
# Day  48
# Go shopping!
# Day  50
# Day  52
# Go shopping!
# Day  54
# Day  56
# Go shopping!
# Day  58
# Day  60
# Go shopping!
# Day  62
# Day  64
# Go shopping!
# Day  66
# Day  68
# Go shopping!
# Day  70
# Day  72
